# %% [markdown]
# #

# %% [markdown]
# # Ｍarkdown教學
# ## 標題二
# ### 標題三
#
# This is a markdown language tutorial.
#
# 文字兩行中間要多空一行，才會換行。
#
# `<br><br>`
#
# 可新增空行，不然分隔線之前不管空的再多，都不會跑出空行
#
# --------------------

# %% [markdown]
# ![%E6%88%AA%E5%9C%96%202022-06-13%20%E4%B8%8B%E5%8D%881.45.07.png](attachment:%E6%88%AA%E5%9C%96%202022-06-13%20%E4%B8%8B%E5%8D%881.45.07.png)

# %% [markdown]
# ![%E6%88%AA%E5%9C%96%202022-06-13%20%E4%B8%8B%E5%8D%881.48.18.png](attachment:%E6%88%AA%E5%9C%96%202022-06-13%20%E4%B8%8B%E5%8D%881.48.18.png)

# %% [markdown]
# 印出哈囉世界！

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# ![%E6%88%AA%E5%9C%96%202022-06-13%20%E4%B8%8B%E5%8D%882.06.00.png](attachment:%E6%88%AA%E5%9C%96%202022-06-13%20%E4%B8%8B%E5%8D%882.06.00.png)

# %% [markdown]
# ![%E6%88%AA%E5%9C%96%202022-06-13%20%E4%B8%8B%E5%8D%882.18.22.png](attachment:%E6%88%AA%E5%9C%96%202022-06-13%20%E4%B8%8B%E5%8D%882.18.22.png)

# %% [markdown]
# --------------------------------------
#
#
# ## 目錄
#
# ### CH1 AI起源
#
# #### 1-1 遍地開花的AI運用
#
# #### 1-2 人工智慧的發展
#
# #### 1-3 人工智慧@台灣
#
# #### 1-4 未來的AI生活
#
# ### CH2 應用篇
#
# #### 2-1 影像處理
#
# #### 2-2 自然語言處理
#
# #### 2-3 邏輯推理
#
# #### 2-4 推薦系統
#
# #### 2-5 疾病預測

# %% [markdown]
# *X+Y* #前後用一個星號包起來，就會變斜體，變數常用斜體表示

# %% [markdown]
# **重要觀念** #前後用兩個星號包起來，就會變粗體

# %% [markdown]
# `$x^2+y^2=1$`
#
# $x^2+y^2=1$

# %% [markdown]
# Latax是用來打數學公式的程式，排版漂亮，全部寫完才做編譯。國外出版社常用Latex檔來出版
# 單錢號前後包夾，可以打數學公式，當作在文章內文的方程式

# %% [markdown]
# 雙引號用來打換行置中的公式，通常用來強調使用的model介紹
#
# `$$\int_a^b x$$`
#
# $$\int_a^b x$$

# %% [markdown]
# `$\int_a^b x$`
# $\int_a^b x$

# %% [markdown]
# #### 常數微分為0
# $$f(x) = 5$$
#
# $$\frac{df(x)}{dx} = 0$$

# %% [markdown]
# $$F = \sum_{n=1}^{100} (x_{n}+x_{n}^{2})$$

# %% [markdown]
# $$f(x)= ax^n$$

# %% [markdown]
# $$ \frac{df(x)}{dx}=anx^{n-1}$$

# %% [markdown]
# $$f(x) = 6x^5 + 4x^4 + 3x^3 + 2x^2 + x + 9$$
#
# $$\frac{df(x)}{dx} = 30x^4 + 16x^3 + 9x^2 + 4x + 1$$

# %% [markdown]
# $$f(x, y) = 2x^3 + 6xy^2 +4y +2$$

# %% [markdown]
# `$$\frac{\partial f(x, y)}{\partial x} = 6x^2+6y^2$$`
#
# $$\frac{\partial f(x, y)}{\partial x} = 6x^2+6y^2$$
#
# `$$\frac{\partial f(x, y)}{\partial y} = 12xy + 4$$`
#
# $$\frac{\partial f(x, y)}{\partial y} = 12xy + 4$$

# %% [markdown]
# ```
# git init
# git add
# git commit
# ```

# %% [markdown]
# ```
# import os
# file = "myFile.txt"
# if os.path.exist(file):
#     os.remove(file)
#     print(file + " is deleted")
# else:
#     print(file + " file is not found")
# ```

# %%
import os
file = "myFile.txt"
if os.path.exists(file):
    os.remove(file)
    print(file + " is deleted")
else:
    print(file + " file is not found")
# Out:
# myFile.txt file is not found

# %% [markdown]
# ## 清單架構
# * 第一點
#     * 1.1
#         * 1.1.1
#     * 1.2
#     * 1.3
# * 第二點
# * 第三點
#
#
# #要空兩行以上，才可以把段落清單分開
# - 第一點
# - 第二點
# - 第三點

# %% [markdown]
# ### 目錄
#
# * CH1 AI起源
#     * 1-1 遍地開花的AI運用
#     * 1-2 人工智慧的發展
#     * 1-3 人工智慧@台灣
#     * 1-4 未來的AI生活
# * CH2 應用篇
#     * 2-1 影像處理
#     * 2-2 自然語言處理
#     * 2-3 邏輯推理
#     * 2-4 推薦系統
#     * 2-5 疾病預測

# %% [markdown]
# ### 數字編號
# 1. 輸出檔案
# 2. 載入檔案
# 3. Markdown
# 4. HTML
# 5. Python

# %% [markdown]
# ### 目錄
# * CH1 AI起源
#     1. 1-1 遍地開花的AI運用
#     2. 1-2 人工智慧的發展
#     3. 1-3 人工智慧@台灣
#     4. 1-4 未來的AI生活
# * CH2 應用篇
#     1. 2-1 影像處理
#     2. 2-2 自然語言處理
#     3. 2-3 邏輯推理
#     4. 2-4 推薦系統
#     5. 2-5 疾病預測

# %% [markdown]
# ![%E6%88%AA%E5%9C%96%202022-06-13%20%E4%B8%8B%E5%8D%883.47.02.png](attachment:%E6%88%AA%E5%9C%96%202022-06-13%20%E4%B8%8B%E5%8D%883.47.02.png)

# %% [markdown]
# ![%E6%88%AA%E5%9C%96%202022-06-13%20%E4%B8%8B%E5%8D%882.59.16.png](attachment:%E6%88%AA%E5%9C%96%202022-06-13%20%E4%B8%8B%E5%8D%882.59.16.png)

# %% [markdown]
# ![%E6%88%AA%E5%9C%96%202022-06-13%20%E4%B8%8B%E5%8D%883.09.39.png](attachment:%E6%88%AA%E5%9C%96%202022-06-13%20%E4%B8%8B%E5%8D%883.09.39.png)
